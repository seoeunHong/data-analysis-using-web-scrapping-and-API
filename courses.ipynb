# %% [markdown]
# # Part 1 - Combine Course Info with Requirements
# ## Import Libraries

# %%
from bs4 import BeautifulSoup
import numpy as np
import pandas as pd
import re

# %% [markdown]
# ## 1. Read the course schedule into a DataFrame

# %%
with open('NYU_CS_Course_Schedule.html', 'r') as HTMLFile:
    dom = BeautifulSoup(HTMLFile, "html.parser")

# %%
schedule = dom.select_one('.schedule-listing')

# %%
courses = schedule.select('li')

# %%
course_schedule_data = []
for course in courses:
    course_data = []
    # Each column's info are stored as 'span' -> select them 
    span_lists = course.select('span')
    # only select necessary info (Number-Section, Name, Instructor, and Time)
    for i, span in enumerate(span_lists[:4]):
        # Extract text data only from html span
        # Some text data contain unnecessary spaces. Deal with this using re.sub(' +', ' ')
        text_info = re.sub(' +', ' ', span.text.strip()).split('\n')
        # Some text in 'Name' columns is formatted differently ('\n' within the Name). Deal with this. 
        if i == 2 and len(text_info) > 1:
            text_info = [text_info[0] + ", " + text_info[-1]]
        # Drop everything except first element 
        # For Number-Section: it only takes first Number-Section which is mainly CSCI
        # For Instructor: It only takes first instructor, Second or other instructors are TA or not main
        # instructors. so decided to drop.
        course_data.append(text_info[0])
    # Replace invisiable space character with empty string
    course_data = list(map(lambda c: c.replace('\u200b',""),course_data))
    course_schedule_data.append(course_data)

# %%
# Make DataFrrame using Pandas by putting 2D array into data and specified feature names into column 
course_schedule = pd.DataFrame(course_schedule_data, columns = ['Number-Section', 'Name', 'Instructor', 'Time'])

# %%
course_schedule
# Out:
#        Number-Section                                               Name  \
# 0    CSCI-GA.1170-001                             Fundamental Algorithms
# 1    CSCI-GA.1170-002                  Fundamental Algorithms Recitation
# 2    CSCI-GA.1180-001        Mathematical Techniques For CS Applications
# 3    CSCI-GA.2110-001                              Programming Languages
# 4    CSCI-GA.2110-002                   Programming Languages Recitation
# ..                ...                                                ...
# 146  CSCI-UA.0480-061                                    Special Topics:
# 147  CSCI-UA.0480-063  Special Topics: Introduction to Computer Security
# 148  CSCI-UA.0480-069  Special Topics: Agile Software Development and...
# 149  CSCI-UA.0480-072                                    Special Topics:
# 150  CSCI-UA.0480-073              Special Topics: Randomized Algorithms
#
#             Instructor             Time
# 0       Yevgeniy Dodis    T 7:10-9:10PM
# 1        Aditya Pandey    R 8:10-9:00PM
# 2         Parijat Dube    W 7:10-9:10PM
# 3           Cory Plock    M 4:55-6:55PM
# 4    Jahnavi Pothineni    R 7:10-8:00PM
# ..                 ...              ...
# 146   Joanna Klukowska  MW 12:30-1:45PM
# 147     Joseph Bonneau   MW 2:00-3:15PM
# 148     Amos Bloomberg  MW 12:30-1:45PM
# 149       Lerrel Pinto   TR 3:30-4:45PM
# 150       Richard Cole  MW 9:30-10:45AM
#
# [151 rows x 4 columns]

# %%
course_schedule[['Number', 'Section']] = course_schedule['Number-Section'].str.extract('(.+)-(\d{3})')

# %%
course_schedule.drop('Number-Section',axis = 1,inplace=True)
course_schedule = course_schedule[['Number', 'Section', 'Name', 'Instructor', 'Time']]

# %%
course_schedule
# Out:
#            Number Section                                               Name  \
# 0    CSCI-GA.1170     001                             Fundamental Algorithms
# 1    CSCI-GA.1170     002                  Fundamental Algorithms Recitation
# 2    CSCI-GA.1180     001        Mathematical Techniques For CS Applications
# 3    CSCI-GA.2110     001                              Programming Languages
# 4    CSCI-GA.2110     002                   Programming Languages Recitation
# ..            ...     ...                                                ...
# 146  CSCI-UA.0480     061                                    Special Topics:
# 147  CSCI-UA.0480     063  Special Topics: Introduction to Computer Security
# 148  CSCI-UA.0480     069  Special Topics: Agile Software Development and...
# 149  CSCI-UA.0480     072                                    Special Topics:
# 150  CSCI-UA.0480     073              Special Topics: Randomized Algorithms
#
#             Instructor             Time
# 0       Yevgeniy Dodis    T 7:10-9:10PM
# 1        Aditya Pandey    R 8:10-9:00PM
# 2         Parijat Dube    W 7:10-9:10PM
# 3           Cory Plock    M 4:55-6:55PM
# 4    Jahnavi Pothineni    R 7:10-8:00PM
# ..                 ...              ...
# 146   Joanna Klukowska  MW 12:30-1:45PM
# 147     Joseph Bonneau   MW 2:00-3:15PM
# 148     Amos Bloomberg  MW 12:30-1:45PM
# 149       Lerrel Pinto   TR 3:30-4:45PM
# 150       Richard Cole  MW 9:30-10:45AM
#
# [151 rows x 5 columns]

# %%
course_schedule.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 151 entries, 0 to 150
# Data columns (total 5 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Number      151 non-null    object
#  1   Section     151 non-null    object
#  2   Name        151 non-null    object
#  3   Instructor  151 non-null    object
#  4   Time        151 non-null    object
# dtypes: object(5)
# memory usage: 6.0+ KB

# %%
course_schedule.head(5)
# Out:
#          Number Section                                         Name  \
# 0  CSCI-GA.1170     001                       Fundamental Algorithms
# 1  CSCI-GA.1170     002            Fundamental Algorithms Recitation
# 2  CSCI-GA.1180     001  Mathematical Techniques For CS Applications
# 3  CSCI-GA.2110     001                        Programming Languages
# 4  CSCI-GA.2110     002             Programming Languages Recitation
#
#           Instructor           Time
# 0     Yevgeniy Dodis  T 7:10-9:10PM
# 1      Aditya Pandey  R 8:10-9:00PM
# 2       Parijat Dube  W 7:10-9:10PM
# 3         Cory Plock  M 4:55-6:55PM
# 4  Jahnavi Pothineni  R 7:10-8:00PM

# %%
course_schedule.tail(5)
# Out:
#            Number Section                                               Name  \
# 146  CSCI-UA.0480     061                                    Special Topics:
# 147  CSCI-UA.0480     063  Special Topics: Introduction to Computer Security
# 148  CSCI-UA.0480     069  Special Topics: Agile Software Development and...
# 149  CSCI-UA.0480     072                                    Special Topics:
# 150  CSCI-UA.0480     073              Special Topics: Randomized Algorithms
#
#            Instructor             Time
# 146  Joanna Klukowska  MW 12:30-1:45PM
# 147    Joseph Bonneau   MW 2:00-3:15PM
# 148    Amos Bloomberg  MW 12:30-1:45PM
# 149      Lerrel Pinto   TR 3:30-4:45PM
# 150      Richard Cole  MW 9:30-10:45AM

# %%
course_schedule.sample(5)
# Out:
#            Number Section                                               Name  \
# 39   CSCI-GA.3205     001            Applied Cryptography & Network Security
# 92   CSCI-UA.0102     004                       Data Structures - Recitation
# 147  CSCI-UA.0480     063  Special Topics: Introduction to Computer Security
# 60   CSCI-UA.0002     004  Intro To Computer Programming (No Prior Experi...
# 42   CSCI-GA.3813     002                                       Adv Lab MS *
#
#          Instructor             Time
# 39    Mazdak Zamani    T 4:55-6:55PM
# 92   Chris Davidson   W 9:30-10:45AM
# 147  Joseph Bonneau   MW 2:00-3:15PM
# 60      Mihir Patil  MW 9:30-10:45AM
# 42            STAFF                -

# %% [markdown]
# ## 2. Read the course catalog into a DataFrame

# %%
with open('NYU_CS_Course_Catalog.html', 'r') as HTMLFile2:
    dom2 = BeautifulSoup(HTMLFile2, 'html.parser')

# %%
catalog = dom2.select_one('.courses-listing')

# %%
courses2 = catalog.select('li')

# %%
course_catalog_data = []
for course in courses2:
    course_data = []
    # Each column's info are stored as 'p' -> select them
    p_list = course.select('p')
    # Extract only necessary info (Course Title, points, and Prereqs)
    for i, p in enumerate(p_list[:3]):
        text_info = re.sub(' +', ' ', p.text.strip()).split('\n')
        # When it's Course Title, Just take first Course Number
        if i == 0:
            text_info = text_info[0].split(" ")[0]
        # When it's Points column, just take points number
        elif i == 1:
            # Extract text that ends with 'Points' using re
            point_list = re.findall('(.+) (Points)', text_info[0])
            if point_list:
                # Take only the number of credits 
                text_info = point_list[0][0]
            else:
                # if they don't have the number of credits, mark as 'NOT SPECIFIED'
                text_info = "NOT SPECIFIED"
        else:
            # When it's Prereqs column, just take contents
            text_info = text_info[0].replace("Prerequisites: ", "")
        course_data.append(text_info)
    course_catalog_data.append(course_data)

# %%
course_catalog = pd.DataFrame(course_catalog_data, columns = ['Number', 'Points', 'Prereqs'])

# %%
course_catalog = course_catalog[['Number', 'Prereqs', 'Points']]

# %%
course_catalog
# Out:
#            Number                                            Prereqs Points
# 0    CSCI-GA.1133                                               None      4
# 1    CSCI-GA.1144           CSCI-GA 1133 or departmental permission.      4
# 2    CSCI-GA.1170  At least one year of experience with a high-le...      3
# 3    CSCI-GA.1180                                               None      3
# 4    CSCI-GA.2110  Students taking this class should already have...      3
# ..            ...                                                ...    ...
# 91   CSCI-UA.0897  Restricted to declared computer science majors...  1 - 4
# 92   CSCI-UA.0898  Restricted to declared computer science majors...  1 - 4
# 93   CSCI-UA.0997  Permission of the department. Does not satisfy...  1 - 4
# 94   CSCI-UA.0998  Permission of the department. Does not satisfy...  1 - 4
# 95  FRSEM-UA.0597  Some programming experience in Python, Java, J...      4
#
# [96 rows x 3 columns]

# %%
course_catalog.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 96 entries, 0 to 95
# Data columns (total 3 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   Number   96 non-null     object
#  1   Prereqs  96 non-null     object
#  2   Points   96 non-null     object
# dtypes: object(3)
# memory usage: 2.4+ KB

# %%
course_catalog.head(5)
# Out:
#          Number                                            Prereqs Points
# 0  CSCI-GA.1133                                               None      4
# 1  CSCI-GA.1144           CSCI-GA 1133 or departmental permission.      4
# 2  CSCI-GA.1170  At least one year of experience with a high-le...      3
# 3  CSCI-GA.1180                                               None      3
# 4  CSCI-GA.2110  Students taking this class should already have...      3

# %%
course_catalog.tail(5)
# Out:
#            Number                                            Prereqs Points
# 91   CSCI-UA.0897  Restricted to declared computer science majors...  1 - 4
# 92   CSCI-UA.0898  Restricted to declared computer science majors...  1 - 4
# 93   CSCI-UA.0997  Permission of the department. Does not satisfy...  1 - 4
# 94   CSCI-UA.0998  Permission of the department. Does not satisfy...  1 - 4
# 95  FRSEM-UA.0597  Some programming experience in Python, Java, J...      4

# %%
course_catalog.sample(5)
# Out:
#            Number                                            Prereqs  \
# 21   CSCI-GA.2437  Prerequisites include experience with Hadoop, ...
# 46   CSCI-GA.3110  Permission of the instructor for master’s stud...
# 45   CSCI-GA.3033             Prerequisites vary according to topic.
# 72   CSCI-UA.0310  Data Structures (CSCI-UA 102); Discrete Mathem...
# 61  MAINT-GA.4747                                               None
#
#            Points
# 21              3
# 46              4
# 45              3
# 72              4
# 61  NOT SPECIFIED

# %% [markdown]
# ## 3. Put together both DataFrames

# %%
CS_course = pd.merge(course_schedule, course_catalog, on = 'Number', how = 'left')

# %%
CS_course
# Out:
#            Number Section                                               Name  \
# 0    CSCI-GA.1170     001                             Fundamental Algorithms
# 1    CSCI-GA.1170     002                  Fundamental Algorithms Recitation
# 2    CSCI-GA.1180     001        Mathematical Techniques For CS Applications
# 3    CSCI-GA.2110     001                              Programming Languages
# 4    CSCI-GA.2110     002                   Programming Languages Recitation
# ..            ...     ...                                                ...
# 146  CSCI-UA.0480     061                                    Special Topics:
# 147  CSCI-UA.0480     063  Special Topics: Introduction to Computer Security
# 148  CSCI-UA.0480     069  Special Topics: Agile Software Development and...
# 149  CSCI-UA.0480     072                                    Special Topics:
# 150  CSCI-UA.0480     073              Special Topics: Randomized Algorithms
#
#             Instructor             Time  \
# 0       Yevgeniy Dodis    T 7:10-9:10PM
# 1        Aditya Pandey    R 8:10-9:00PM
# 2         Parijat Dube    W 7:10-9:10PM
# 3           Cory Plock    M 4:55-6:55PM
# 4    Jahnavi Pothineni    R 7:10-8:00PM
# ..                 ...              ...
# 146   Joanna Klukowska  MW 12:30-1:45PM
# 147     Joseph Bonneau   MW 2:00-3:15PM
# 148     Amos Bloomberg  MW 12:30-1:45PM
# 149       Lerrel Pinto   TR 3:30-4:45PM
# 150       Richard Cole  MW 9:30-10:45AM
#
#                                                Prereqs Points
# 0    At least one year of experience with a high-le...      3
# 1    At least one year of experience with a high-le...      3
# 2                                                 None      3
# 3    Students taking this class should already have...      3
# 4    Students taking this class should already have...      3
# ..                                                 ...    ...
# 146                    Topics determine prerequisites.      4
# 147                    Topics determine prerequisites.      4
# 148                    Topics determine prerequisites.      4
# 149                    Topics determine prerequisites.      4
# 150                    Topics determine prerequisites.      4
#
# [151 rows x 7 columns]

# %%
pd.set_option('display.max_rows', 200)

# %%
display(CS_course)
# Out:
#             Number Section                                               Name  \
# 0     CSCI-GA.1170     001                             Fundamental Algorithms
# 1     CSCI-GA.1170     002                  Fundamental Algorithms Recitation
# 2     CSCI-GA.1180     001        Mathematical Techniques For CS Applications
# 3     CSCI-GA.2110     001                              Programming Languages
# 4     CSCI-GA.2110     002                   Programming Languages Recitation
# 5     CSCI-GA.2130     001                              Compiler Construction
# 6     CSCI-GA.2250     001                                  Operating Systems
# 7     CSCI-GA.2250     002                                  Operating Systems
# 8     CSCI-GA.2262     001                   Data Communications and Networks
# 9     CSCI-GA.2270     001                                  Computer Graphics
# 10    CSCI-GA.2421     001                               Numerical Methods II
# 11    CSCI-GA.2433     001                                   Database Systems
# 12    CSCI-GA.2436     001                    Realtime and Big Data Analytics
# 13    CSCI-GA.2560     001                            Artificial Intelligence
# 14    CSCI-GA.2566     001                   Foundations Of Machine Learning*
# 15    CSCI-GA.2572     001                                      Deep Learning
# 16    CSCI-GA.2572     002                                  Deep Learning Lab
# 17    CSCI-GA.2590     001                        Natural Language Processing
# 18    CSCI-GA.2620     001                        Networks and Mobile Systems
# 19    CSCI-GA.2820     001                     DevOps and Agile Methodologies
# 20    CSCI-GA.2820     002                 DevOps and Agile Methodologies Lab
# 21    CSCI-GA.2820     003                     DevOps and Agile Methodologies
# 22    CSCI-GA.2820     004                 DevOps and Agile Methodologies Lab
# 23    CSCI-GA.2830     001                               The Lean Launch Pad*
# 24    CSCI-GA.2830     002                           The Lean Launch Pad Lab*
# 25    CSCI-GA.2945     002  Adv Topics Num Analysis: High Performance Comp...
# 26    CSCI-GA.2945     003  Adv Topics Num Analysis: Immersed Boundary Met...
# 27    CSCI-GA.3033     029                                    Special Topics:
# 28    CSCI-GA.3033     034                                    Special Topics:
# 29    CSCI-GA.3033     059                                    Special Topics:
# 30    CSCI-GA.3033     076                                    Special Topics:
# 31    CSCI-GA.3033     077                                    Special Topics:
# 32    CSCI-GA.3033     085                                    Special Topics:
# 33    CSCI-GA.3033     097                                    Special Topics:
# 34    CSCI-GA.3033     098  Special Topics in DS: Data Science for Healthcare
# 35    CSCI-GA.3033     099  Special Topics in DS: Introduction to Computer...
# 36    CSCI-GA.3033     198  Special Topics in DS: Data Science for Healthc...
# 37    CSCI-GA.3033     199  Special Topics in DS: Introduction to Computer...
# 38    CSCI-GA.3140     001                            Abstract Interpretation
# 39    CSCI-GA.3205     001            Applied Cryptography & Network Security
# 40    CSCI-GA.3812     001                  Information Technology Projects *
# 41    CSCI-GA.3813     001                                       Adv Lab MS *
# 42    CSCI-GA.3813     002                                       Adv Lab MS *
# 43    CSCI-GA.3813     003                                       Adv Lab MS *
# 44    CSCI-GA.3813     004                                       Adv Lab MS *
# 45    CSCI-GA.3813     005                                     Adv Lab PhD **
# 46    CSCI-GA.3813     006                                     Adv Lab PhD **
# 47    CSCI-GA.3813     007                                     Adv Lab PhD **
# 48    CSCI-GA.3813     008                                     Adv Lab PhD **
# 49    CSCI-GA.3840     001                         Master's Thesis Research *
# 50    CSCI-GA.3850     001                        PhD Seminar: Cryptography**
# 51    CSCI-GA.3850     004                      PhD Seminar: Formal Methods**
# 52    CSCI-GA.3860     001                             PhD Thesis Research **
# 53    CSCI-GA.3870     001                 Internship In Computer Science MS*
# 54    CSCI-GA.3870     002                Internship in Computer Science PhD*
# 55   MAINT-GA.4747     001         Maintenance of Matriculation (MS Students)
# 56   MAINT-GA.4747     004  Maintenance of Matriculation (non-supported Ph...
# 57    CSCI-UA.0002     001  Intro To Computer Programming (No Prior Experi...
# 58    CSCI-UA.0002     002  Intro To Computer Programming (No Prior Experi...
# 59    CSCI-UA.0002     003  Intro To Computer Programming (No Prior Experi...
# 60    CSCI-UA.0002     004  Intro To Computer Programming (No Prior Experi...
# 61    CSCI-UA.0002     005  Intro To Computer Programming (No Prior Experi...
# 62    CSCI-UA.0002     006  Intro To Computer Programming (No Prior Experi...
# 63    CSCI-UA.0002     007  Intro To Computer Programming (No Prior Experi...
# 64    CSCI-UA.0002     008  Intro To Computer Programming (No Prior Experi...
# 65    CSCI-UA.0002     009  Intro To Computer Programming (No Prior Experi...
# 66    CSCI-UA.0002     010  Intro To Computer Programming (No Prior Experi...
# 67    CSCI-UA.0002     011  Intro To Computer Programming (No Prior Experi...
# 68    CSCI-UA.0002     012  Intro To Computer Programming (No Prior Experi...
# 69    CSCI-UA.0002     013  Intro To Computer Programming (No Prior Experi...
# 70    CSCI-UA.0003     001  Intro to Computer Programming (Limited Prior E...
# 71    CSCI-UA.0004     001          Intro to Web Design & Computer Principles
# 72    CSCI-UA.0004     002          Intro to Web Design & Computer Principles
# 73    CSCI-UA.0004     003          Intro to Web Design & Computer Principles
# 74    CSCI-UA.0004     004          Intro to Web Design & Computer Principles
# 75    CSCI-UA.0004     005          Intro to Web Design & Computer Principles
# 76    CSCI-UA.0004     006          Intro to Web Design & Computer Principles
# 77    CSCI-UA.0060     001                 Database Design And Implementation
# 78    CSCI-UA.0061     001                    Web Development And Programming
# 79    CSCI-UA.0101     001                          Intro To Computer Science
# 80    CSCI-UA.0101     002                          Intro To Computer Science
# 81    CSCI-UA.0101     003                          Intro To Computer Science
# 82    CSCI-UA.0101     004                          Intro To Computer Science
# 83    CSCI-UA.0101     005                          Intro To Computer Science
# 84    CSCI-UA.0101     006                          Intro To Computer Science
# 85    CSCI-UA.0101     007                          Intro To Computer Science
# 86    CSCI-UA.0101     008                          Intro To Computer Science
# 87    CSCI-UA.0101     009                          Intro To Computer Science
# 88    CSCI-UA.0101     010                          Intro To Computer Science
# 89    CSCI-UA.0102     001                                    Data Structures
# 90    CSCI-UA.0102     002                       Data Structures - Recitation
# 91    CSCI-UA.0102     003                                    Data Structures
# 92    CSCI-UA.0102     004                       Data Structures - Recitation
# 93    CSCI-UA.0102     005                                    Data Structures
# 94    CSCI-UA.0102     006                       Data Structures - Recitation
# 95    CSCI-UA.0102     021                       Data Structures - Recitation
# 96    CSCI-UA.0102     061                       Data Structures - Recitation
# 97    CSCI-UA.0102     062                       Data Structures - Recitation
# 98    CSCI-UA.0102     063                       Data Structures - Recitation
# 99    CSCI-UA.0102     064                       Data Structures - Recitation
# 100   CSCI-UA.0102     065                       Data Structures - Recitation
# 101   CSCI-UA.0201     001                      Computer Systems Organization
# 102   CSCI-UA.0201     002         Computer Systems Organization - Recitation
# 103   CSCI-UA.0201     003                      Computer Systems Organization
# 104   CSCI-UA.0201     004         Computer Systems Organization - Recitation
# 105   CSCI-UA.0201     005                      Computer Systems Organization
# 106   CSCI-UA.0201     006         Computer Systems Organization - Recitation
# 107   CSCI-UA.0201     007                      Computer Systems Organization
# 108   CSCI-UA.0201     008         Computer Systems Organization - Recitation
# 109   CSCI-UA.0201     021         Computer Systems Organization - Recitation
# 110   CSCI-UA.0201     041         Computer Systems Organization - Recitation
# 111   CSCI-UA.0201     061         Computer Systems Organization - Recitation
# 112   CSCI-UA.0201     081         Computer Systems Organization - Recitation
# 113   CSCI-UA.0202     001                                  Operating Systems
# 114   CSCI-UA.0202     002                                  Operating Systems
# 115   CSCI-UA.0310     001                                   Basic Algorithms
# 116   CSCI-UA.0310     002                      Basic Algorithms - Recitation
# 117   CSCI-UA.0310     003                                   Basic Algorithms
# 118   CSCI-UA.0310     004                      Basic Algorithms - Recitation
# 119   CSCI-UA.0310     005                                   Basic Algorithms
# 120   CSCI-UA.0310     007                                   Basic Algorithms
# 121   CSCI-UA.0310     008                      Basic Algorithms - Recitation
# 122   CSCI-UA.0310     021                      Basic Algorithms - Recitation
# 123   CSCI-UA.0310     041                      Basic Algorithms - Recitation
# 124   CSCI-UA.0310     061                      Basic Algorithms - Recitation
# 125   CSCI-UA.0310     081                      Basic Algorithms - Recitation
# 126   CSCI-UA.0330     001                Introduction to Computer Simulation
# 127   CSCI-UA.0330     002                Introduction to Computer Simulation
# 128   CSCI-UA.0380     001     Topics of General Interest: Drawing on the Web
# 129   CSCI-UA.0381     001           Programming Tools for the Data Scientist
# 130   CSCI-UA.0421     001                                Numerical Computing
# 131   CSCI-UA.0453     001                              Theory Of Computation
# 132   CSCI-UA.0467     001                        Applied Internet Technology
# 133   CSCI-UA.0467     002                        Applied Internet Technology
# 134   CSCI-UA.0470     001                        Object Oriented Programming
# 135   CSCI-UA.0472     001                            Artificial Intelligence
# 136   CSCI-UA.0473     001                   Fundamentals of Machine Learning
# 137   CSCI-UA.0473     002      Fundamentals of Machine Learning - Recitation
# 138   CSCI-UA.0473     021      Fundamentals of Machine Learning - Recitation
# 139   CSCI-UA.0476     001     Processing Big Data for Analytics Applications
# 140   CSCI-UA.0478     001                       Introduction To Cryptography
# 141   CSCI-UA.0479     001                       Data Management and Analysis
# 142   CSCI-UA.0479     002                       Data Management and Analysis
# 143   CSCI-UA.0480     041                  Special Topics: Computer Graphics
# 144   CSCI-UA.0480     051                 Special Topics: Parallel Computing
# 145   CSCI-UA.0480     057        Special Topics: Natural Language Processing
# 146   CSCI-UA.0480     061                                    Special Topics:
# 147   CSCI-UA.0480     063  Special Topics: Introduction to Computer Security
# 148   CSCI-UA.0480     069  Special Topics: Agile Software Development and...
# 149   CSCI-UA.0480     072                                    Special Topics:
# 150   CSCI-UA.0480     073              Special Topics: Randomized Algorithms
#
#                            Instructor              Time  \
# 0                      Yevgeniy Dodis     T 7:10-9:10PM
# 1                       Aditya Pandey     R 8:10-9:00PM
# 2                        Parijat Dube     W 7:10-9:10PM
# 3                          Cory Plock     M 4:55-6:55PM
# 4                   Jahnavi Pothineni     R 7:10-8:00PM
# 5                   Joseph Tassarotti     M 7:10-9:10PM
# 6                     Hubertus Franke     M 7:10-9:10PM
# 7                           Yang Tang     T 4:55-6:55PM
# 8              Jean-Claude Franchitti     M 7:10-9:10PM
# 9                     Daniele Panozzo     R 4:55-6:55PM
# 10                   Aleksandar Donev     T 5:10-7:00PM
# 11                 Matthew Zeidenberg     W 4:55-6:55PM
# 12                          Yang Tang     R 4:55-6:55PM
# 13                         Paul Bethe     M 4:55-6:55PM
# 14                      Mehryar Mohri     T 4:55-6:55PM
# 15      Yann LeCun,  Alfredo Canziani     W 4:55-6:55PM
# 16                   Alfredo Canziani     R 4:55-5:45PM
# 17                              He He     T 4:55-6:55PM
# 18                  Anirudh Sivaraman   W 10:15-12:15PM
# 19                       John Rofrano     T 4:55-6:55PM
# 20                       John Rofrano     T 7:10-8:00PM
# 21                       John Rofrano     W 4:55-6:55PM
# 22                       John Rofrano     W 7:10-8:00PM
# 23                   Yiannis Broustas   R 10:15-12:15PM
# 24                   Yiannis Broustas    R 12:30-1:20PM
# 25                      Georg Stadler     M 5:10-7:00PM
# 26                     Charles Peskin   M 11:00-12:50PM
# 27                 Bhubaneswar Mishra     R 4:55-6:55PM
# 28                     Mohamed Zahran     W 4:55-6:55PM
# 29                        Anasse Bari     W 4:55-6:55PM
# 30                        Davi Geiger     W 7:10-9:10PM
# 31                      Aurojit Panda     W 7:10-9:10PM
# 32              I-Hsin Chung,  Hao Yu     R 4:55-6:55PM
# 33                     Kenneth Perlin     T 4:55-6:55PM
# 34                     Jacopo Cirrone     F 2:00-3:40PM
# 35                         Jean Ponce     M 4:55-6:35PM
# 36                       Pranav Singh     T 3:45-4:35PM
# 37                         Jean Ponce     R 5:55-6:45PM
# 38                     Patrick Cousot     M 4:55-6:55PM
# 39                      Mazdak Zamani     T 4:55-6:55PM
# 40                         Evan Korth     W 5:00-8:00PM
# 41                              STAFF                 -
# 42                              STAFF                 -
# 43                              STAFF                 -
# 44                              STAFF                 -
# 45                              STAFF                 -
# 46                              STAFF                 -
# 47                              STAFF                 -
# 48                              STAFF                 -
# 49                              STAFF                 -
# 50                     Yevgeniy Dodis    T 12:30-3:15PM
# 51                        Thomas Wies   R 11:00-12:30PM
# 52                              STAFF                 -
# 53                              STAFF                 -
# 54                              STAFF                 -
# 55                              STAFF                 -
# 56                              STAFF                 -
# 57                    Amanda Steigman    MW 8:00-9:15AM
# 58                         Susan Liao    TR 8:00-9:15AM
# 59                         Craig Kapp   MW 9:30-10:45AM
# 60                        Mihir Patil   MW 9:30-10:45AM
# 61                      Julie Lizardo  MW 11:00-12:15PM
# 62                      Julie Lizardo  TR 11:00-12:15PM
# 63                       David Prager   MW 12:30-1:45PM
# 64                     Joshua Clayton   TR 12:30-1:45PM
# 65                         Emily Zhao    MW 2:00-3:15PM
# 66                         Emily Zhao    TR 2:00-3:15PM
# 67                 Matthew Zeidenberg    MW 3:30-4:45PM
# 68                     Khye Borg Liew    TR 3:30-4:45PM
# 69                    Michell Cardona    TR 6:20-7:35PM
# 70                        Adam Meyers  MW 11:00-12:15PM
# 71                       Alvaro Olsen    MW 8:00-9:15AM
# 72                         Adam Scher    TR 8:00-9:15AM
# 73                     Joshua Clayton   TR 9:30-10:45AM
# 74                         Mark Ramos  MW 11:00-12:15PM
# 75                      Julie Lizardo    TR 2:00-3:15PM
# 76                       Alvaro Olsen    MW 3:30-4:45PM
# 77                     Amos Bloomberg   TR 12:30-1:45PM
# 78                         Craig Kapp   MW 12:30-1:45PM
# 79                       Nader Nassar    MW 8:00-9:15AM
# 80        Gabriel Provencher Langlois    TR 8:00-9:15AM
# 81                        Gizem Kayar   TR 9:30-10:45AM
# 82                        Anasse Bari  TR 11:00-12:15PM
# 83                       Candido Cabo   MW 12:30-1:45PM
# 84              Hilbert Gene Locklear   TR 12:30-1:45PM
# 85              Hilbert Gene Locklear    MW 2:00-3:15PM
# 86                     Amos Bloomberg    TR 2:00-3:15PM
# 87                        Michael Tao    MW 3:30-4:45PM
# 88                        Daniel Zint    TR 3:30-4:45PM
# 89                         Evan Korth    MW 3:30-4:45PM
# 90                Adithya Viswanathan     F 3:30-4:45PM
# 91                        Anasse Bari    TR 2:00-3:15PM
# 92                     Chris Davidson    W 9:30-10:45AM
# 93                   Joanna Klukowska    MW 8:00-9:15AM
# 94                   Surya Dheeshjith   F 11:00-12:15PM
# 95                       Vaibhav Mavi     F 3:30-4:45PM
# 96                        Joel Tellis   F 11:00-12:15PM
# 97                   Surya Dheeshjith    F 9:30-10:45AM
# 98                    Anirudh Nistala    R 9:30-10:45AM
# 99                   Joseph Cappadona     F 2:00-3:15PM
# 100                       Joel Tellis     R 2:00-3:15PM
# 101                     Douglas Moody   MW 9:30-10:45AM
# 102         Shraddha Thyagarajan Iyer    F 9:30-10:45AM
# 103                       Gizem Kayar  MW 11:00-12:15PM
# 104                      Vaibhav Mavi     R 4:55-6:10PM
# 105                  Hasan Aljabbouli   TR 9:30-10:45AM
# 106                     Swapnil Gupta     W 8:00-9:15AM
# 107            Jean-Claude Franchitti    MW 3:30-4:45PM
# 108                          Yang Gao     F 3:30-4:45PM
# 109             Jaya Amit Sai Gurrala    F 9:30-10:45AM
# 110  Sai Krishna Chaitanya Annavazala     R 4:55-6:10PM
# 111         Shraddha Thyagarajan Iyer     W 8:00-9:15AM
# 112                   Joanna Gilberti     F 3:30-4:45PM
# 113                   Michael Walfish    MW 3:30-4:45PM
# 114                         Yang Tang   TR 12:30-1:45PM
# 115   Seyed Hossein Nassajianmojarrad   TR 12:30-1:45PM
# 116               Abishek Shyamsunder   F 11:00-12:15PM
# 117                        Oded Regev    TR 8:00-9:15AM
# 118                     Ishan Agarwal     W 8:00-9:15AM
# 119                       Alan Siegel    MW 2:00-3:15PM
# 120                Vladimir Podolskii  MW 11:00-12:15PM
# 121                      Majid Daliri   F 11:00-12:15PM
# 122                   Shantanu Dahiya   F 11:00-12:15PM
# 123                       Aaron Zweig     W 8:00-9:15AM
# 124                       Alan Siegel     F 2:00-3:15PM
# 125                     Lakshay Tyagi   F 11:00-12:15PM
# 126                    Charles Peskin  TR 11:00-12:15PM
# 127               Claire Nicole Valva   F 11:00-12:15PM
# 128                    Joshua Clayton    MW 3:30-4:45PM
# 129                  Hasan Aljabbouli  TR 11:00-12:15PM
# 130                   Michael Overton    TR 2:00-3:15PM
# 131                      Subhash Khot   TR 9:30-10:45AM
# 132                    Joseph Versoza   MW 12:30-1:45PM
# 133                    Joseph Versoza   TR 9:30-10:45AM
# 134                  Hasan Aljabbouli    TR 2:00-3:15PM
# 135                      Ernest Davis  MW 11:00-12:15PM
# 136                   Pascal Wallisch   MW 12:30-1:45PM
# 137              Kaushik Tummalapalli    R 12:30-1:45PM
# 138                 Inder Preet Walia    R 12:30-1:45PM
# 139                       Ann Malavet    TR 8:00-9:15AM
# 140                         CANCELLED                 -
# 141                    Joseph Versoza   MW 9:30-10:45AM
# 142                Matthew Zeidenberg    TR 3:30-4:45PM
# 143                       Gizem Kayar   TR 12:30-1:45PM
# 144                    Mohamed Zahran    TR 2:00-3:15PM
# 145                       Adam Meyers   TR 9:30-10:45AM
# 146                  Joanna Klukowska   MW 12:30-1:45PM
# 147                    Joseph Bonneau    MW 2:00-3:15PM
# 148                    Amos Bloomberg   MW 12:30-1:45PM
# 149                      Lerrel Pinto    TR 3:30-4:45PM
# 150                      Richard Cole   MW 9:30-10:45AM
#
#                                                Prereqs                Points
# 0    At least one year of experience with a high-le...                     3
# 1    At least one year of experience with a high-le...                     3
# 2                                                 None                     3
# 3    Students taking this class should already have...                     3
# 4    Students taking this class should already have...                     3
# 5        CSCI-GA 1170, CSCI-GA 2110, and CSCI-GA 2250.                     3
# 6                                                 None                     3
# 7                                                 None                     3
# 8    Students must have a working knowledge of fund...                     3
# 9    CSCI-GA 1170 and CSCI-UA 140 (or an equivalent...                     3
# 10                        Corequisite: linear algebra.                     3
# 11                                                None                     3
# 12                                                None                     3
# 13                                                None                     3
# 14                                       CSCI-GA 1180.                     3
# 15   DS-GA 1001 Intro to Data Science or a graduate...                     3
# 16   DS-GA 1001 Intro to Data Science or a graduate...                     3
# 17   Some facility with Java and Python and a knowl...                     3
# 18       CSCI-GA 1170, CSCI-GA 2110, and CSCI-GA 2250.                     3
# 19                                                None                     3
# 20                                                None                     3
# 21                                                None                     3
# 22                                                None                     3
# 23                                                None                     3
# 24                                                None                     3
# 25                     Topics determine prerequisites.                     3
# 26                     Topics determine prerequisites.                     3
# 27              Prerequisites vary according to topic.                     3
# 28              Prerequisites vary according to topic.                     3
# 29              Prerequisites vary according to topic.                     3
# 30              Prerequisites vary according to topic.                     3
# 31              Prerequisites vary according to topic.                     3
# 32              Prerequisites vary according to topic.                     3
# 33              Prerequisites vary according to topic.                     3
# 34              Prerequisites vary according to topic.                     3
# 35              Prerequisites vary according to topic.                     3
# 36              Prerequisites vary according to topic.                     3
# 37              Prerequisites vary according to topic.                     3
# 38   Some facility with logic, sets, linear algebra...                     3
# 39                                                None                     3
# 40   For MS in IS students: Successful completion o...                     3
# 41   Permission of the faculty project supervisor a...  1-3 (MS), 1-12 (PhD)
# 42   Permission of the faculty project supervisor a...  1-3 (MS), 1-12 (PhD)
# 43   Permission of the faculty project supervisor a...  1-3 (MS), 1-12 (PhD)
# 44   Permission of the faculty project supervisor a...  1-3 (MS), 1-12 (PhD)
# 45   Permission of the faculty project supervisor a...  1-3 (MS), 1-12 (PhD)
# 46   Permission of the faculty project supervisor a...  1-3 (MS), 1-12 (PhD)
# 47   Permission of the faculty project supervisor a...  1-3 (MS), 1-12 (PhD)
# 48   Permission of the faculty project supervisor a...  1-3 (MS), 1-12 (PhD)
# 49   Approval of a faculty adviser and the Director...                 3 - 6
# 50                       Permission of the instructor.                     1
# 51                       Permission of the instructor.                     1
# 52   Permission of the thesis adviser or director o...                1 - 12
# 53         Permission of Director of Graduate Studies.                   1-3
# 54         Permission of Director of Graduate Studies.                   1-3
# 55                                                None         NOT SPECIFIED
# 56                                                None         NOT SPECIFIED
# 57   Three years of high school mathematics or equi...                     4
# 58   Three years of high school mathematics or equi...                     4
# 59   Three years of high school mathematics or equi...                     4
# 60   Three years of high school mathematics or equi...                     4
# 61   Three years of high school mathematics or equi...                     4
# 62   Three years of high school mathematics or equi...                     4
# 63   Three years of high school mathematics or equi...                     4
# 64   Three years of high school mathematics or equi...                     4
# 65   Three years of high school mathematics or equi...                     4
# 66   Three years of high school mathematics or equi...                     4
# 67   Three years of high school mathematics or equi...                     4
# 68   Three years of high school mathematics or equi...                     4
# 69   Three years of high school mathematics or equi...                     4
# 70   Limited programming experience, or any score o...                     4
# 71   Three years of high school mathematics or equi...                     4
# 72   Three years of high school mathematics or equi...                     4
# 73   Three years of high school mathematics or equi...                     4
# 74   Three years of high school mathematics or equi...                     4
# 75   Three years of high school mathematics or equi...                     4
# 76   Three years of high school mathematics or equi...                     4
# 77   Introduction to Computer Programming (No Prior...                     4
# 78   Introduction to Computer Programming (No Prior...                     4
# 79   Introduction to Computer Programming (No Prior...                     4
# 80   Introduction to Computer Programming (No Prior...                     4
# 81   Introduction to Computer Programming (No Prior...                     4
# 82   Introduction to Computer Programming (No Prior...                     4
# 83   Introduction to Computer Programming (No Prior...                     4
# 84   Introduction to Computer Programming (No Prior...                     4
# 85   Introduction to Computer Programming (No Prior...                     4
# 86   Introduction to Computer Programming (No Prior...                     4
# 87   Introduction to Computer Programming (No Prior...                     4
# 88   Introduction to Computer Programming (No Prior...                     4
# 89   Introduction to Computer Science (CSCI-UA 101)...                     4
# 90   Introduction to Computer Science (CSCI-UA 101)...                     4
# 91   Introduction to Computer Science (CSCI-UA 101)...                     4
# 92   Introduction to Computer Science (CSCI-UA 101)...                     4
# 93   Introduction to Computer Science (CSCI-UA 101)...                     4
# 94   Introduction to Computer Science (CSCI-UA 101)...                     4
# 95   Introduction to Computer Science (CSCI-UA 101)...                     4
# 96   Introduction to Computer Science (CSCI-UA 101)...                     4
# 97   Introduction to Computer Science (CSCI-UA 101)...                     4
# 98   Introduction to Computer Science (CSCI-UA 101)...                     4
# 99   Introduction to Computer Science (CSCI-UA 101)...                     4
# 100  Introduction to Computer Science (CSCI-UA 101)...                     4
# 101                     Data Structures (CSCI-UA 102).                     4
# 102                     Data Structures (CSCI-UA 102).                     4
# 103                     Data Structures (CSCI-UA 102).                     4
# 104                     Data Structures (CSCI-UA 102).                     4
# 105                     Data Structures (CSCI-UA 102).                     4
# 106                     Data Structures (CSCI-UA 102).                     4
# 107                     Data Structures (CSCI-UA 102).                     4
# 108                     Data Structures (CSCI-UA 102).                     4
# 109                     Data Structures (CSCI-UA 102).                     4
# 110                     Data Structures (CSCI-UA 102).                     4
# 111                     Data Structures (CSCI-UA 102).                     4
# 112                     Data Structures (CSCI-UA 102).                     4
# 113       Computer Systems Organization (CSCI-UA 201).                     4
# 114       Computer Systems Organization (CSCI-UA 201).                     4
# 115  Data Structures (CSCI-UA 102); Discrete Mathem...                     4
# 116  Data Structures (CSCI-UA 102); Discrete Mathem...                     4
# 117  Data Structures (CSCI-UA 102); Discrete Mathem...                     4
# 118  Data Structures (CSCI-UA 102); Discrete Mathem...                     4
# 119  Data Structures (CSCI-UA 102); Discrete Mathem...                     4
# 120  Data Structures (CSCI-UA 102); Discrete Mathem...                     4
# 121  Data Structures (CSCI-UA 102); Discrete Mathem...                     4
# 122  Data Structures (CSCI-UA 102); Discrete Mathem...                     4
# 123  Data Structures (CSCI-UA 102); Discrete Mathem...                     4
# 124  Data Structures (CSCI-UA 102); Discrete Mathem...                     4
# 125  Data Structures (CSCI-UA 102); Discrete Mathem...                     4
# 126  A grade of C or higher in MATH-UA 121 Calculus...                     4
# 127  A grade of C or higher in MATH-UA 121 Calculus...                     4
# 128                    Topics determine prerequisites.                     4
# 129  Data Science for Everyone (DS-UA 111) or equiv...                     4
# 130  Computer Systems Organization (CSCI-UA 201), e...                     4
# 131  Basic Algorithms (CSCI-UA 310) and Computer Sy...                     4
# 132  C or better in Computer Systems Organization (...                     4
# 133  C or better in Computer Systems Organization (...                     4
# 134       Computer Systems Organization (CSCI-UA 201).                     4
# 135  Computer Systems Organization (CSCI-UA 201) an...                     4
# 136  Data Structures (CSCI-UA.102), Linear Algebra ...                     4
# 137  Data Structures (CSCI-UA.102), Linear Algebra ...                     4
# 138  Data Structures (CSCI-UA.102), Linear Algebra ...                     4
# 139  (CSCI-UA 201) Computer Systems Organization an...                     4
# 140                    Basic Algorithms (CSCI-UA 310).                     4
# 141  Data Structures (CSCI-UA 102). Students that c...                     4
# 142  Data Structures (CSCI-UA 102). Students that c...                     4
# 143                    Topics determine prerequisites.                     4
# 144                    Topics determine prerequisites.                     4
# 145                    Topics determine prerequisites.                     4
# 146                    Topics determine prerequisites.                     4
# 147                    Topics determine prerequisites.                     4
# 148                    Topics determine prerequisites.                     4
# 149                    Topics determine prerequisites.                     4
# 150                    Topics determine prerequisites.                     4

# %% [markdown]
# ## 4. Conclusion

# %% [markdown]
# I confronted several unexpected data format.
#
# 1. when I deal with course data in course schedule page, some text data within `span` contain unnecessary space and this made me hard to extract contents only. To deal with this problem I used `sub` method of `regular expression (re)` to substitute unnecessary large space(more than two space) to one space. (' +' -> ' ') `re.sub(' +', ' ', span.text.strip())`. After that, split it by `\n` and take the first information. `text_info = re.sub(' +', ' ', span.text.strip()).split('\n')` The reason why I only take the first one is second one is mostly not exist (unnecessary space) or additional information we do not that much needed, so I decided to drop the others. However, the `Name` column sometimes include uncessary space and another professor and noticed that when I split with `\n`, it returns `[first professor, ' ', ' ', second professor]` Therefore, I decided when we are dealing with name column and if they had multiple professors (no more than 2), we just take first and last element from the list we get after split. `if i == 2 and len(text_info) > 1: text_info = [text_info[0] + text_info[-1]]`.
#
# 2. After that, sometimes, our data contain invisible space character `\u220b`. To deal with this issue, I used replace method to replace `\u220b` to "". `course_data = list(map(lambda c: c.replace('\u200b',""),course_data))`.
#
# 3. when I deal with course data in course catalog page, also some text data within `p` contain unnecessary space. I deal with this the same way that I did previously. ` text_info = re.sub(' +', ' ', p.text.strip()).split('\n')`. Other columns' data is all expected, but I faced some difficulties when I deal with `Points` column. Some courses, they have various points or even do not have points at all. The way that I approach to this issue was first extract all info before `Points` string using `findall` method of `regular expression (re)`. `point_list = re.findall('(.+) (Points)', text_info[0])`. And then, if they have information before the `Points` string (Either just one digits or range of digits - such as 1-4 ), I just take that information, or if they do not have any information before `Points` string, I just put `NOT SPECIFIED` to indicate this course do not specified its credits.
#
# And in this particular DataFrames, we used `how=left` when we merge two DataFrames. This parameter put your second DataFrame on the very left of the first DataFrame but only merge data that is intersection with first DataFrame based on the key that specified `on` paramater.

# %%
print(course_schedule.head())
# Out:
#          Number Section                                         Name  \
# 0  CSCI-GA.1170     001                       Fundamental Algorithms
# 1  CSCI-GA.1170     002            Fundamental Algorithms Recitation
# 2  CSCI-GA.1180     001  Mathematical Techniques For CS Applications
# 3  CSCI-GA.2110     001                        Programming Languages
# 4  CSCI-GA.2110     002             Programming Languages Recitation
#
#           Instructor           Time
# 0     Yevgeniy Dodis  T 7:10-9:10PM
# 1      Aditya Pandey  R 8:10-9:00PM
# 2       Parijat Dube  W 7:10-9:10PM
# 3         Cory Plock  M 4:55-6:55PM
# 4  Jahnavi Pothineni  R 7:10-8:00PM
